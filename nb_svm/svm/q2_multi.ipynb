# %%
#Importing all the necessary libraries
import numpy as np
import pandas as pd
import time
from cvxopt import solvers
from cvxopt import matrix
from scipy.spatial.distance import pdist, cdist, squareform
from sklearn.svm import SVC
from multiprocessing import Process

# %%
#Importing data
s = time.time()
data = pd.read_csv('../fashion_mnist/train.csv', header=None)
data = data.to_numpy()
print("Data imported in: ", time.time()-s, "s")
C = 1
gamma = 0.05
# Out:
# Data imported in:  3.7777106761932373 s

# %%
#Function to extract subset of data, for two desired classes
def extract_data(d, d_prime):
    
    index_d = np.argwhere(data[:,-1]==d)[:,0]
    index_dp = np.argwhere(data[:,-1]==d_prime)[:,0]
    
    count1 = index_d.shape[0]
    count2 = index_dp.shape[0]
    
    return count1, count2, np.concatenate( (data[index_d, :-1], data[index_dp, :-1]), axis = 0)

# %%
#Function to train a binary classifier for two desired classes
#Returns the learnt value of alphas and intercept b
def binary_classifier(d, dp):
    
    count_d, count_dp, data_d_dp = extract_data(d, dp)
    data_d_dp /= 255

    y_d = np.full(count_d, -1).reshape(-1,1)
    y_dp = np.full(count_dp, 1).reshape(-1,1)

    y = np.concatenate((y_d, y_dp), axis = 0)
    y_d = []
    y_dp = []
    
    s = time.time()
    P_g = squareform(pdist(data_d_dp))
    P_g = np.exp(-gamma*np.square(P_g))
    P_gaussian = matrix(np.multiply(np.matmul(y, y.T), P_g))
    print("Kernel Computed for ", d," & ", dp, " in ", time.time()-s,"s")
    
    q = matrix(-np.ones((count_d+count_dp, 1)))
    G = matrix(np.concatenate((np.eye(count_d+count_dp)*-1,np.eye(count_d+count_dp)), axis = 0))
    h = matrix(np.concatenate((np.zeros(count_d+count_dp), np.ones(count_d+count_dp) * C), axis = None))
    b_solver = matrix(np.zeros(1))
    A = matrix(y.reshape(1, -1), tc='d')
    
    s = time.time()
    solution_gaussian = solvers.qp(P_gaussian, q, G, h, A, b_solver)
    print("Gaussian Solved for ", d," & ", dp, " in ", time.time()-s,"s")
    alphas_gaussian = np.array(solution_gaussian['x'])
    
    alpha_y = (y * alphas_gaussian)
    b_0 = np.max(np.matmul(P_g[:count_d,:], alpha_y))
    b_1 = np.min(np.matmul(P_g[count_d:,:], alpha_y))
    P_g = []
    b = (-b_0-b_1)/2
    
    return (alphas_gaussian, b)

# %%
#Enumerating the desired models of binary classifiers
n=10
ids = []
for i in range(n):
    for j in range(i+1, n):
        ids.append((i,j))

alphas = []
b = np.zeros((n,n))

# %%
batchsize = 1
#Training 45 different models of binary classifiers
#Tried doing it with help of multiprocessing but was of no use, since the CVXOPT solver itself uses 4 threads.
s1 = time.time()
for i in range(int(45/batchsize)):
    
    print("Going for batch ", i)
    
    s = time.time()
    for j in range(batchsize):
        
        d, dp = ids[i*batchsize + j]
        
        alphas_g, b_g = binary_classifier(d,dp)
        
        alphas.append((alphas_g, d, dp))
        b[d, dp] = b_g
#         p = Process(target=binary_classifier, args=(n, m))
#         p.start()
#         processes.append(p)
#     for p in processes:
#         p.join()
    print("Done for batch ", i, " in ", time.time()-s)
print("One vs One Done in ", time.time()-s1, "s")
# Out:
# Going for batch  0
# Kernel Computed for  0  &  1  in  6.877500772476196 s
#      pcost       dcost       gap    pres   dres
#  0: -1.6492e+02 -6.6070e+03  3e+04  2e+00  5e-15
#  1: -1.1407e+02 -3.0686e+03  5e+03  2e-01  4e-15
#  2: -1.0459e+02 -7.6952e+02  9e+02  3e-02  5e-15
#  3: -1.2684e+02 -3.0203e+02  2e+02  6e-03  4e-15
#  4: -1.4133e+02 -2.0101e+02  6e+01  1e-03  3e-15
#  5: -1.4945e+02 -1.6809e+02  2e+01  2e-04  3e-15
#  6: -1.5144e+02 -1.6280e+02  1e+01  3e-05  3e-15
#  7: -1.5364e+02 -1.5728e+02  4e+00  7e-06  3e-15
#  8: -1.5443e+02 -1.5550e+02  1e+00  2e-13  3e-15
#  9: -1.5478e+02 -1.5492e+02  1e-01  2e-13  3e-15
# 10: -1.5483e+02 -1.5484e+02  4e-03  1e-13  3e-15
# 11: -1.5483e+02 -1.5483e+02  6e-05  2e-13  3e-15
# Optimal solution found.
# Gaussian Solved for  0  &  1  in  25.952956438064575 s
# Done for batch  0  in  33.34030222892761
# Going for batch  1
# Kernel Computed for  0  &  2  in  7.200037002563477 s
#      pcost       dcost       gap    pres   dres
#  0: -3.7366e+02 -8.4330e+03  4e+04  2e+00  6e-15
#  1: -2.8341e+02 -4.5691e+03  7e+03  2e-01  5e-15
#  2: -2.6181e+02 -1.1549e+03  1e+03  3e-02  6e-15
#  3: -3.1375e+02 -5.8168e+02  3e+02  6e-03  5e-15
#  4: -3.4227e+02 -4.1865e+02  8e+01  1e-03  5e-15
#  5: -3.5409e+02 -3.7849e+02  2e+01  2e-04  5e-15
#  6: -3.5907e+02 -3.6537e+02  6e+00  2e-05  5e-15
#  7: -3.6070e+02 -3.6180e+02  1e+00  2e-06  5e-15
#  8: -3.6105e+02 -3.6113e+02  8e-02  1e-07  5e-15
#  9: -3.6108e+02 -3.6108e+02  2e-03  3e-09  5e-15
# 10: -3.6108e+02 -3.6108e+02  4e-05  4e-11  5e-15
# Optimal solution found.
# Gaussian Solved for  0  &  2  in  26.79937219619751 s
# Done for batch  1  in  34.54217767715454
# Going for batch  2
# Kernel Computed for  0  &  3  in  7.3333587646484375 s
#      pcost       dcost       gap    pres   dres
#  0: -5.0649e+02 -8.5038e+03  4e+04  2e+00  9e-15
#  1: -4.0102e+02 -4.7685e+03  7e+03  2e-01  9e-15
#  2: -3.8628e+02 -1.1830e+03  9e+02  2e-02  1e-14
#  3: -4.5117e+02 -7.2740e+02  3e+02  6e-03  9e-15
#  4: -4.8441e+02 -5.8062e+02  1e+02  1e-03  9e-15
#  5: -5.0013e+02 -5.2734e+02  3e+01  2e-05  1e-14
#  6: -5.0580e+02 -5.1293e+02  7e+00  1e-06  1e-14
#  7: -5.0772e+02 -5.0866e+02  9e-01  1e-13  1e-14
#  8: -5.0800e+02 -5.0814e+02  1e-01  9e-13  1e-14
#  9: -5.0805e+02 -5.0806e+02  6e-03  9e-13  1e-14
# 10: -5.0805e+02 -5.0805e+02  2e-04  5e-13  1e-14
# Optimal solution found.
# Gaussian Solved for  0  &  3  in  25.251352787017822 s
# Done for batch  2  in  33.089991331100464
# Going for batch  3
# Kernel Computed for  0  &  4  in  6.992368459701538 s
#      pcost       dcost       gap    pres   dres
#  0: -2.6859e+02 -7.0722e+03  3e+04  2e+00  6e-15
#  1: -1.9279e+02 -3.5589e+03  5e+03  2e-01  4e-15
#  2: -1.7237e+02 -8.6876e+02  9e+02  3e-02  5e-15
#  3: -2.1276e+02 -4.3671e+02  3e+02  7e-03  4e-15
#  4: -2.3708e+02 -3.0397e+02  7e+01  1e-03  3e-15
#  5: -2.4834e+02 -2.6677e+02  2e+01  3e-04  4e-15
#  6: -2.5227e+02 -2.5748e+02  5e+00  6e-05  3e-15
#  7: -2.5364e+02 -2.5461e+02  1e+00  3e-13  4e-15
#  8: -2.5398e+02 -2.5404e+02  5e-02  3e-13  4e-15
#  9: -2.5400e+02 -2.5401e+02  1e-03  1e-13  4e-15
# 10: -2.5400e+02 -2.5400e+02  3e-05  1e-13  4e-15
# Optimal solution found.
# Gaussian Solved for  0  &  4  in  25.147958993911743 s
# Done for batch  3  in  32.636898040771484
# Going for batch  4
# Kernel Computed for  0  &  5  in  7.0910539627075195 s
#      pcost       dcost       gap    pres   dres
#  0: -1.9696e+02 -7.3592e+03  3e+04  2e+00  5e-15
#  1: -1.3157e+02 -3.7922e+03  6e+03  2e-01  3e-15
#  2: -1.0046e+02 -9.5864e+02  1e+03  4e-02  5e-15
#  3: -1.3521e+02 -3.4380e+02  2e+02  7e-03  3e-15
#  4: -1.5380e+02 -2.1468e+02  6e+01  8e-04  2e-15
#  5: -1.6312e+02 -1.8376e+02  2e+01  3e-13  2e-15
#  6: -1.6683e+02 -1.7392e+02  7e+00  6e-14  2e-15
#  7: -1.6823e+02 -1.7056e+02  2e+00  2e-13  2e-15
#  8: -1.6889e+02 -1.6928e+02  4e-01  2e-16  2e-15
#  9: -1.6902e+02 -1.6904e+02  2e-02  4e-14  2e-15
# 10: -1.6903e+02 -1.6903e+02  3e-04  1e-13  2e-15
# 11: -1.6903e+02 -1.6903e+02  4e-06  2e-13  2e-15
# Optimal solution found.
# Gaussian Solved for  0  &  5  in  27.38109850883484 s
# Done for batch  4  in  34.98761034011841
# Going for batch  5
# Kernel Computed for  0  &  6  in  7.0962395668029785 s
#      pcost       dcost       gap    pres   dres
#  0: -1.0396e+03 -9.5846e+03  4e+04  2e+00  1e-14
#  1: -8.6974e+02 -5.8661e+03  7e+03  2e-01  2e-14
#  2: -8.9358e+02 -1.8092e+03  1e+03  2e-02  2e-14
#  3: -9.9727e+02 -1.2864e+03  3e+02  5e-03  2e-14
#  4: -1.0441e+03 -1.1319e+03  9e+01  8e-04  2e-14
#  5: -1.0607e+03 -1.0851e+03  2e+01  2e-04  2e-14
#  6: -1.0662e+03 -1.0717e+03  6e+00  3e-05  2e-14
#  7: -1.0675e+03 -1.0687e+03  1e+00  4e-06  2e-14
#  8: -1.0679e+03 -1.0679e+03  5e-02  3e-08  2e-14
#  9: -1.0679e+03 -1.0679e+03  1e-03  6e-10  2e-14
# Optimal solution found.
# Gaussian Solved for  0  &  6  in  22.66910147666931 s
# Done for batch  5  in  30.268432140350342
# Going for batch  6
# Kernel Computed for  0  &  7  in  7.196300029754639 s
#      pcost       dcost       gap    pres   dres
#  0: -1.0789e+02 -7.4144e+03  4e+04  2e+00  5e-15
#  1: -5.8581e+01 -3.7245e+03  6e+03  3e-01  3e-15
#  2: -1.8417e+01 -8.7407e+02  1e+03  4e-02  7e-15
#  3: -3.8829e+01 -1.9635e+02  2e+02  5e-03  4e-15
#  4: -5.5771e+01 -1.0639e+02  5e+01  1e-03  2e-15
#  5: -6.3792e+01 -8.0947e+01  2e+01  1e-04  2e-15
#  6: -6.7399e+01 -7.2673e+01  5e+00  2e-05  2e-15
#  7: -6.8657e+01 -7.0232e+01  2e+00  1e-06  2e-15
#  8: -6.9169e+01 -6.9365e+01  2e-01  9e-09  2e-15
#  9: -6.9247e+01 -6.9257e+01  1e-02  4e-10  2e-15
# 10: -6.9251e+01 -6.9251e+01  2e-04  6e-12  2e-15
# 11: -6.9251e+01 -6.9251e+01  3e-06  9e-14  2e-15
# Optimal solution found.
# Gaussian Solved for  0  &  7  in  27.237224578857422 s
# Done for batch  6  in  34.95253610610962
# Going for batch  7
# Kernel Computed for  0  &  8  in  7.1506431102752686 s
#      pcost       dcost       gap    pres   dres
#  0: -2.7984e+02 -7.6220e+03  3e+04  2e+00  5e-15
#  1: -2.0299e+02 -4.0371e+03  6e+03  2e-01  3e-15
#  2: -1.7493e+02 -1.2336e+03  1e+03  4e-02  4e-15
#  3: -2.1659e+02 -4.2387e+02  2e+02  6e-03  3e-15
#  4: -2.4162e+02 -2.9524e+02  6e+01  7e-04  2e-15
#  5: -2.5192e+02 -2.6612e+02  1e+01  1e-04  2e-15
#  6: -2.5529e+02 -2.5891e+02  4e+00  2e-05  2e-15
#  7: -2.5634e+02 -2.5681e+02  5e-01  8e-07  2e-15
#  8: -2.5650e+02 -2.5653e+02  3e-02  4e-08  2e-15
#  9: -2.5651e+02 -2.5651e+02  6e-04  7e-10  2e-15
# 10: -2.5651e+02 -2.5651e+02  1e-05  1e-11  2e-15
# Optimal solution found.
# Gaussian Solved for  0  &  8  in  25.25519609451294 s
# Done for batch  7  in  32.90975332260132
# Going for batch  8
# Kernel Computed for  0  &  9  in  7.163895130157471 s
#      pcost       dcost       gap    pres   dres
#  0: -1.3464e+02 -6.8388e+03  3e+04  2e+00  5e-15
#  1: -7.6690e+01 -3.2910e+03  5e+03  2e-01  2e-15
#  2: -5.4390e+01 -6.8811e+02  8e+02  3e-02  4e-15
#  3: -8.6653e+01 -2.4599e+02  2e+02  5e-03  3e-15
#  4: -1.0255e+02 -1.5246e+02  5e+01  1e-03  2e-15
#  5: -1.0963e+02 -1.2739e+02  2e+01  3e-04  2e-15
#  6: -1.1318e+02 -1.1820e+02  5e+00  4e-05  2e-15
#  7: -1.1445e+02 -1.1556e+02  1e+00  4e-06  2e-15
#  8: -1.1479e+02 -1.1496e+02  2e-01  5e-07  2e-15
#  9: -1.1485e+02 -1.1486e+02  5e-03  9e-09  2e-15
# 10: -1.1485e+02 -1.1485e+02  1e-04  2e-10  2e-15
# Optimal solution found.
# Gaussian Solved for  0  &  9  in  25.02873420715332 s
# Done for batch  8  in  32.70578193664551
# Going for batch  9
# Kernel Computed for  1  &  2  in  7.074766635894775 s
#      pcost       dcost       gap    pres   dres
#  0: -1.3552e+02 -7.1330e+03  3e+04  2e+00  5e-15
#  1: -8.6508e+01 -3.3924e+03  5e+03  2e-01  3e-15
#  2: -7.2456e+01 -7.5584e+02  9e+02  3e-02  3e-15
#  3: -9.8211e+01 -2.9087e+02  2e+02  6e-03  3e-15
#  4: -1.1260e+02 -1.7965e+02  7e+01  2e-03  2e-15
#  5: -1.2011e+02 -1.4295e+02  2e+01  3e-04  2e-15
#  6: -1.2381e+02 -1.3099e+02  7e+00  1e-13  2e-15
#  7: -1.2520e+02 -1.2765e+02  2e+00  1e-13  2e-15
#  8: -1.2579e+02 -1.2645e+02  7e-01  4e-14  2e-15
#  9: -1.2601e+02 -1.2606e+02  5e-02  4e-14  2e-15
# 10: -1.2603e+02 -1.2603e+02  1e-03  6e-14  2e-15
# 11: -1.2603e+02 -1.2603e+02  1e-05  8e-14  2e-15
# Optimal solution found.
# Gaussian Solved for  1  &  2  in  27.401801109313965 s
# Done for batch  9  in  34.98771119117737
# Going for batch  10
# Kernel Computed for  1  &  3  in  7.061944007873535 s
#      pcost       dcost       gap    pres   dres
#  0: -2.2920e+02 -7.6513e+03  4e+04  2e+00  6e-15
#  1: -1.5609e+02 -3.9103e+03  6e+03  2e-01  6e-15
#  2: -1.3600e+02 -9.2629e+02  1e+03  3e-02  7e-15
#  3: -1.7295e+02 -4.3323e+02  3e+02  7e-03  5e-15
#  4: -1.9647e+02 -2.7544e+02  8e+01  1e-03  5e-15
#  5: -2.0746e+02 -2.3515e+02  3e+01  1e-04  5e-15
#  6: -2.1226e+02 -2.2191e+02  1e+01  2e-05  5e-15
#  7: -2.1376e+02 -2.1815e+02  4e+00  2e-13  6e-15
#  8: -2.1495e+02 -2.1581e+02  9e-01  7e-13  5e-15
#  9: -2.1517e+02 -2.1539e+02  2e-01  7e-13  6e-15
# 10: -2.1525e+02 -2.1526e+02  7e-03  9e-14  5e-15
# 11: -2.1526e+02 -2.1526e+02  1e-04  2e-13  5e-15
# Optimal solution found.
# Gaussian Solved for  1  &  3  in  27.41170310974121 s
# Done for batch  10  in  34.97573447227478
# Going for batch  11
# Kernel Computed for  1  &  4  in  6.967263221740723 s
#      pcost       dcost       gap    pres   dres
#  0: -1.2784e+02 -6.4239e+03  3e+04  2e+00  5e-15
#  1: -8.0058e+01 -2.9152e+03  4e+03  2e-01  3e-15
#  2: -6.9558e+01 -6.4681e+02  7e+02  3e-02  3e-15
#  3: -9.4376e+01 -2.5073e+02  2e+02  5e-03  3e-15
#  4: -1.0877e+02 -1.5571e+02  5e+01  7e-04  2e-15
#  5: -1.1554e+02 -1.3286e+02  2e+01  1e-04  2e-15
#  6: -1.1887e+02 -1.2384e+02  5e+00  2e-06  2e-15
#  7: -1.2010e+02 -1.2121e+02  1e+00  5e-14  2e-15
#  8: -1.2044e+02 -1.2063e+02  2e-01  9e-14  2e-15
#  9: -1.2051e+02 -1.2052e+02  1e-02  2e-13  2e-15
# 10: -1.2052e+02 -1.2052e+02  2e-04  2e-16  2e-15
# 11: -1.2052e+02 -1.2052e+02  9e-06  1e-13  2e-15
# Optimal solution found.
# Gaussian Solved for  1  &  4  in  27.211877584457397 s
# Done for batch  11  in  34.69297122955322
# Going for batch  12
# Kernel Computed for  1  &  5  in  7.082801342010498 s
#      pcost       dcost       gap    pres   dres
#  0: -9.3956e+01 -6.5185e+03  3e+04  2e+00  5e-15
#  1: -5.0069e+01 -2.9491e+03  5e+03  2e-01  2e-15
#  2: -3.9046e+01 -6.7825e+02  8e+02  3e-02  3e-15
#  3: -6.0172e+01 -2.0557e+02  2e+02  5e-03  3e-15
#  4: -7.2614e+01 -1.1949e+02  5e+01  1e-03  2e-15
#  5: -7.7575e+01 -9.6388e+01  2e+01  1e-04  2e-15
#  6: -7.9825e+01 -8.8992e+01  9e+00  1e-13  1e-15
#  7: -8.1322e+01 -8.4537e+01  3e+00  6e-14  1e-15
#  8: -8.1909e+01 -8.3041e+01  1e+00  1e-14  1e-15
#  9: -8.2190e+01 -8.2488e+01  3e-01  6e-14  1e-15
# 10: -8.2279e+01 -8.2332e+01  5e-02  4e-14  1e-15
# 11: -8.2299e+01 -8.2300e+01  2e-03  4e-14  2e-15
# 12: -8.2299e+01 -8.2299e+01  2e-05  8e-14  2e-15
# Optimal solution found.
# Gaussian Solved for  1  &  5  in  29.53013277053833 s
# Done for batch  12  in  37.12085771560669
# Going for batch  13
# Kernel Computed for  1  &  6  in  7.082186222076416 s
#      pcost       dcost       gap    pres   dres
#  0: -1.6321e+02 -6.5609e+03  3e+04  2e+00  5e-15
#  1: -1.1075e+02 -3.0589e+03  5e+03  2e-01  3e-15
#  2: -1.0167e+02 -7.6887e+02  9e+02  3e-02  4e-15
#  3: -1.2535e+02 -3.1952e+02  2e+02  7e-03  3e-15
#  4: -1.4028e+02 -2.0638e+02  7e+01  2e-03  3e-15
#  5: -1.4794e+02 -1.7118e+02  2e+01  2e-04  3e-15
#  6: -1.5107e+02 -1.6136e+02  1e+01  1e-05  3e-15
#  7: -1.5295e+02 -1.5632e+02  3e+00  3e-06  3e-15
#  8: -1.5376e+02 -1.5442e+02  7e-01  7e-14  3e-15
#  9: -1.5397e+02 -1.5405e+02  8e-02  9e-14  3e-15
# 10: -1.5400e+02 -1.5400e+02  2e-03  2e-13  3e-15
# 11: -1.5400e+02 -1.5400e+02  6e-05  7e-14  3e-15
# Optimal solution found.
# Gaussian Solved for  1  &  6  in  27.534271001815796 s
# Done for batch  13  in  35.10800886154175
# Going for batch  14
# Kernel Computed for  1  &  7  in  7.02839207649231 s
#      pcost       dcost       gap    pres   dres
#  0: -6.5955e+01 -6.5221e+03  3e+04  2e+00  5e-15
#  1: -3.1834e+01 -2.9574e+03  5e+03  2e-01  2e-15
#  2: -1.0088e+01 -5.1383e+02  7e+02  2e-02  5e-15
#  3: -2.7978e+01 -1.2024e+02  1e+02  3e-03  3e-15
#  4: -3.8190e+01 -7.0454e+01  3e+01  8e-04  2e-15
#  5: -4.2441e+01 -5.6406e+01  1e+01  3e-04  2e-15
#  6: -4.4726e+01 -5.0658e+01  6e+00  5e-05  1e-15
#  7: -4.5554e+01 -4.8795e+01  3e+00  9e-14  1e-15
#  8: -4.6276e+01 -4.7407e+01  1e+00  2e-14  1e-15
#  9: -4.6545e+01 -4.6900e+01  4e-01  1e-14  2e-15
# 10: -4.6685e+01 -4.6706e+01  2e-02  5e-14  2e-15
# 11: -4.6694e+01 -4.6695e+01  4e-04  8e-14  2e-15
# 12: -4.6694e+01 -4.6694e+01  5e-06  4e-14  2e-15
# Optimal solution found.
# Gaussian Solved for  1  &  7  in  29.696648836135864 s
# Done for batch  14  in  37.218098163604736
# Going for batch  15
# Kernel Computed for  1  &  8  in  7.158324956893921 s
#      pcost       dcost       gap    pres   dres
#  0: -1.1469e+02 -6.6612e+03  3e+04  2e+00  5e-15
#  1: -6.4473e+01 -3.0959e+03  5e+03  2e-01  2e-15
#  2: -5.1691e+01 -7.9899e+02  1e+03  3e-02  3e-15
#  3: -7.6800e+01 -2.6329e+02  2e+02  6e-03  3e-15
#  4: -9.2410e+01 -1.4435e+02  5e+01  1e-03  2e-15
#  5: -9.8364e+01 -1.1956e+02  2e+01  3e-04  2e-15
#  6: -1.0088e+02 -1.1105e+02  1e+01  7e-14  2e-15
#  7: -1.0257e+02 -1.0606e+02  3e+00  2e-13  1e-15
#  8: -1.0324e+02 -1.0426e+02  1e+00  1e-13  2e-15
#  9: -1.0355e+02 -1.0367e+02  1e-01  8e-14  2e-15
# 10: -1.0359e+02 -1.0359e+02  5e-03  4e-14  2e-15
# 11: -1.0359e+02 -1.0359e+02  1e-04  5e-14  2e-15
# 12: -1.0359e+02 -1.0359e+02  2e-06  1e-13  2e-15
# Optimal solution found.
# Gaussian Solved for  1  &  8  in  30.006033420562744 s
# Done for batch  15  in  37.657103300094604
# Going for batch  16
# Kernel Computed for  1  &  9  in  7.090749740600586 s
#      pcost       dcost       gap    pres   dres
#  0: -7.7086e+01 -6.2810e+03  3e+04  2e+00  4e-15
#  1: -3.6190e+01 -2.7260e+03  4e+03  2e-01  2e-15
#  2: -2.6916e+01 -5.5124e+02  7e+02  2e-02  3e-15
#  3: -4.8738e+01 -1.5892e+02  1e+02  3e-03  3e-15
#  4: -5.9871e+01 -9.4267e+01  4e+01  8e-04  2e-15
#  5: -6.4611e+01 -7.7166e+01  1e+01  1e-04  2e-15
#  6: -6.6205e+01 -7.3281e+01  7e+00  8e-06  1e-15
#  7: -6.7614e+01 -6.9700e+01  2e+00  2e-06  1e-15
#  8: -6.8024e+01 -6.8779e+01  8e-01  1e-13  1e-15
#  9: -6.8259e+01 -6.8394e+01  1e-01  6e-14  1e-15
# 10: -6.8310e+01 -6.8315e+01  5e-03  1e-13  1e-15
# 11: -6.8312e+01 -6.8312e+01  1e-04  3e-14  1e-15
# 12: -6.8312e+01 -6.8312e+01  2e-06  4e-14  1e-15
# Optimal solution found.
# Gaussian Solved for  1  &  9  in  29.72202754020691 s
# Done for batch  16  in  37.313968658447266
# Going for batch  17
# Kernel Computed for  2  &  3  in  6.959599733352661 s
#      pcost       dcost       gap    pres   dres
#  0: -3.0404e+02 -8.2833e+03  4e+04  2e+00  5e-15
#  1: -2.1981e+02 -4.4663e+03  7e+03  3e-01  4e-15
#  2: -1.8274e+02 -1.0106e+03  1e+03  3e-02  6e-15
#  3: -2.3561e+02 -4.7608e+02  3e+02  6e-03  4e-15
#  4: -2.6244e+02 -3.3488e+02  8e+01  1e-03  4e-15
#  5: -2.7389e+02 -2.9769e+02  2e+01  2e-04  4e-15
#  6: -2.7877e+02 -2.8539e+02  7e+00  4e-05  4e-15
#  7: -2.8041e+02 -2.8192e+02  2e+00  3e-06  4e-15
#  8: -2.8091e+02 -2.8102e+02  1e-01  7e-08  4e-15
#  9: -2.8095e+02 -2.8095e+02  2e-03  9e-10  4e-15
# 10: -2.8095e+02 -2.8095e+02  4e-05  1e-11  4e-15
# Optimal solution found.
# Gaussian Solved for  2  &  3  in  25.0304856300354 s
# Done for batch  17  in  32.491734981536865
# Going for batch  18
# Kernel Computed for  2  &  4  in  7.05895733833313 s
#      pcost       dcost       gap    pres   dres
#  0: -9.4630e+02 -1.0583e+04  5e+04  3e+00  1e-14
#  1: -7.4464e+02 -6.9192e+03  9e+03  3e-01  2e-14
#  2: -7.6719e+02 -1.7237e+03  1e+03  2e-02  2e-14
#  3: -8.9919e+02 -1.2167e+03  3e+02  4e-03  2e-14
#  4: -9.4723e+02 -1.0952e+03  1e+02  1e-03  2e-14
#  5: -9.7572e+02 -1.0167e+03  4e+01  2e-04  2e-14
#  6: -9.8536e+02 -9.9280e+02  7e+00  1e-05  2e-14
#  7: -9.8745e+02 -9.8827e+02  8e-01  1e-07  2e-14
#  8: -9.8772e+02 -9.8774e+02  3e-02  3e-09  2e-14
#  9: -9.8773e+02 -9.8773e+02  5e-04  5e-11  2e-14
# Optimal solution found.
# Gaussian Solved for  2  &  4  in  22.717193841934204 s
# Done for batch  18  in  30.277273893356323
# Going for batch  19
# Kernel Computed for  2  &  5  in  7.110743284225464 s
#      pcost       dcost       gap    pres   dres
#  0: -1.8703e+02 -7.3989e+03  3e+04  2e+00  5e-15
#  1: -1.1528e+02 -3.8473e+03  6e+03  2e-01  3e-15
#  2: -8.4105e+01 -8.9248e+02  1e+03  3e-02  5e-15
#  3: -1.3537e+02 -2.8753e+02  2e+02  4e-03  3e-15
#  4: -1.5511e+02 -2.0703e+02  5e+01  7e-04  2e-15
#  5: -1.6371e+02 -1.8115e+02  2e+01  8e-05  2e-15
#  6: -1.6703e+02 -1.7283e+02  6e+00  3e-06  2e-15
#  7: -1.6834e+02 -1.6982e+02  1e+00  9e-14  2e-15
#  8: -1.6876e+02 -1.6899e+02  2e-01  3e-14  2e-15
#  9: -1.6884e+02 -1.6885e+02  8e-03  1e-13  2e-15
# 10: -1.6885e+02 -1.6885e+02  1e-04  4e-14  2e-15
# Optimal solution found.
# Gaussian Solved for  2  &  5  in  25.409032344818115 s
# Done for batch  19  in  33.02194428443909
# Going for batch  20
# Kernel Computed for  2  &  6  in  6.396619081497192 s
#      pcost       dcost       gap    pres   dres
#  0: -9.6781e+02 -1.0280e+04  5e+04  3e+00  1e-14
#  1: -7.7941e+02 -6.5268e+03  8e+03  2e-01  2e-14
#  2: -8.3083e+02 -1.8673e+03  1e+03  2e-02  2e-14
#  3: -9.4685e+02 -1.2637e+03  3e+02  5e-03  2e-14
#  4: -9.9989e+02 -1.0807e+03  8e+01  7e-04  2e-14
#  5: -1.0159e+03 -1.0374e+03  2e+01  1e-04  2e-14
#  6: -1.0214e+03 -1.0238e+03  2e+00  8e-06  2e-14
#  7: -1.0221e+03 -1.0223e+03  2e-01  6e-07  2e-14
#  8: -1.0222e+03 -1.0222e+03  7e-03  1e-08  2e-14
#  9: -1.0222e+03 -1.0222e+03  2e-04  2e-10  2e-14
# Optimal solution found.
# Gaussian Solved for  2  &  6  in  21.66515326499939 s
# Done for batch  20  in  28.550618410110474
# Going for batch  21
# Kernel Computed for  2  &  7  in  6.303195953369141 s
#      pcost       dcost       gap    pres   dres
#  0: -1.0352e+02 -7.4392e+03  4e+04  2e+00  5e-15
#  1: -5.2259e+01 -3.7516e+03  6e+03  3e-01  3e-15
#  2: -1.0077e+01 -8.8825e+02  1e+03  4e-02  8e-15
#  3: -3.5635e+01 -1.9440e+02  2e+02  5e-03  4e-15
#  4: -5.4188e+01 -1.0235e+02  5e+01  9e-04  3e-15
#  5: -6.2019e+01 -7.9857e+01  2e+01  1e-04  2e-15
#  6: -6.5729e+01 -7.1122e+01  5e+00  5e-06  2e-15
#  7: -6.7167e+01 -6.8294e+01  1e+00  3e-07  2e-15
#  8: -6.7544e+01 -6.7677e+01  1e-01  2e-08  2e-15
#  9: -6.7596e+01 -6.7602e+01  6e-03  4e-14  2e-15
# 10: -6.7599e+01 -6.7599e+01  9e-05  4e-14  2e-15
# 11: -6.7599e+01 -6.7599e+01  3e-06  1e-13  2e-15
# Optimal solution found.
# Gaussian Solved for  2  &  7  in  26.044519662857056 s
# Done for batch  21  in  32.831955432891846
# Going for batch  22
# Kernel Computed for  2  &  8  in  6.303529739379883 s
#      pcost       dcost       gap    pres   dres
#  0: -2.7490e+02 -7.4241e+03  3e+04  2e+00  5e-15
#  1: -1.9123e+02 -3.9068e+03  6e+03  2e-01  3e-15
#  2: -1.6914e+02 -1.0114e+03  1e+03  3e-02  4e-15
#  3: -2.2772e+02 -4.2201e+02  2e+02  5e-03  3e-15
#  4: -2.5292e+02 -3.0412e+02  5e+01  8e-04  2e-15
#  5: -2.6267e+02 -2.7651e+02  1e+01  1e-04  2e-15
#  6: -2.6583e+02 -2.6927e+02  3e+00  2e-05  2e-15
#  7: -2.6678e+02 -2.6733e+02  6e-01  3e-06  2e-15
#  8: -2.6696e+02 -2.6699e+02  3e-02  1e-07  2e-15
#  9: -2.6697e+02 -2.6697e+02  6e-04  2e-09  2e-15
# 10: -2.6697e+02 -2.6697e+02  1e-05  2e-11  2e-15
# Optimal solution found.
# Gaussian Solved for  2  &  8  in  23.84317445755005 s
# Done for batch  22  in  30.630217790603638
# Going for batch  23
# Kernel Computed for  2  &  9  in  6.312634229660034 s
#      pcost       dcost       gap    pres   dres
#  0: -1.3122e+02 -6.8313e+03  3e+04  2e+00  5e-15
#  1: -6.8632e+01 -3.3021e+03  5e+03  2e-01  2e-15
#  2: -4.4226e+01 -5.7527e+02  6e+02  2e-02  5e-15
#  3: -8.9948e+01 -1.9526e+02  1e+02  2e-03  3e-15
#  4: -1.0529e+02 -1.3890e+02  3e+01  6e-04  2e-15
#  5: -1.1181e+02 -1.2245e+02  1e+01  1e-04  2e-15
#  6: -1.1461e+02 -1.1691e+02  2e+00  8e-06  2e-15
#  7: -1.1534e+02 -1.1566e+02  3e-01  3e-07  2e-15
#  8: -1.1546e+02 -1.1548e+02  2e-02  4e-09  2e-15
#  9: -1.1546e+02 -1.1547e+02  5e-04  1e-10  2e-15
# 10: -1.1546e+02 -1.1546e+02  1e-05  2e-12  2e-15
# Optimal solution found.
# Gaussian Solved for  2  &  9  in  23.775829553604126 s
# Done for batch  23  in  30.574470043182373
# Going for batch  24
# Kernel Computed for  3  &  4  in  6.2995665073394775 s
#      pcost       dcost       gap    pres   dres
#  0: -4.2846e+02 -7.6683e+03  3e+04  2e+00  7e-15
#  1: -3.2882e+02 -4.1247e+03  6e+03  2e-01  6e-15
#  2: -3.0989e+02 -9.4797e+02  7e+02  2e-02  7e-15
#  3: -3.7592e+02 -5.6057e+02  2e+02  4e-03  6e-15
#  4: -4.0510e+02 -4.5864e+02  6e+01  7e-04  6e-15
#  5: -4.1586e+02 -4.3199e+02  2e+01  1e-04  7e-15
#  6: -4.1976e+02 -4.2383e+02  4e+00  1e-05  7e-15
#  7: -4.2092e+02 -4.2164e+02  7e-01  2e-13  7e-15
#  8: -4.2117e+02 -4.2123e+02  6e-02  3e-13  7e-15
#  9: -4.2119e+02 -4.2119e+02  1e-03  4e-13  7e-15
# 10: -4.2119e+02 -4.2119e+02  2e-05  5e-13  7e-15
# Optimal solution found.
# Gaussian Solved for  3  &  4  in  23.90083146095276 s
# Done for batch  24  in  30.688509464263916
# Going for batch  25
# Kernel Computed for  3  &  5  in  6.300772666931152 s
#      pcost       dcost       gap    pres   dres
#  0: -1.5808e+02 -7.8955e+03  4e+04  2e+00  5e-15
#  1: -8.8651e+01 -4.1551e+03  7e+03  3e-01  2e-15
#  2: -4.1501e+01 -1.0107e+03  1e+03  4e-02  5e-15
#  3: -8.5729e+01 -2.6576e+02  2e+02  5e-03  3e-15
#  4: -1.0518e+02 -1.7631e+02  8e+01  2e-03  2e-15
#  5: -1.1475e+02 -1.4040e+02  3e+01  3e-04  2e-15
#  6: -1.1877e+02 -1.2916e+02  1e+01  3e-14  2e-15
#  7: -1.2050e+02 -1.2484e+02  4e+00  7e-14  2e-15
#  8: -1.2142e+02 -1.2270e+02  1e+00  6e-14  2e-15
#  9: -1.2181e+02 -1.2194e+02  1e-01  7e-14  2e-15
# 10: -1.2186e+02 -1.2187e+02  1e-02  2e-16  2e-15
# 11: -1.2186e+02 -1.2186e+02  2e-04  1e-13  2e-15
# 12: -1.2186e+02 -1.2186e+02  3e-06  2e-13  2e-15
# Optimal solution found.
# Gaussian Solved for  3  &  5  in  28.29784345626831 s
# Done for batch  25  in  35.08386826515198
# Going for batch  26
# Kernel Computed for  3  &  6  in  6.3073890209198 s
#      pcost       dcost       gap    pres   dres
#  0: -5.1433e+02 -9.6131e+03  5e+04  3e+00  8e-15
#  1: -3.9419e+02 -5.7409e+03  8e+03  3e-01  8e-15
#  2: -3.6455e+02 -1.3710e+03  1e+03  2e-02  8e-15
#  3: -4.4119e+02 -7.5464e+02  3e+02  5e-03  8e-15
#  4: -4.7842e+02 -5.8509e+02  1e+02  5e-04  8e-15
#  5: -4.9392e+02 -5.2894e+02  4e+01  1e-04  8e-15
#  6: -4.9931e+02 -5.1319e+02  1e+01  3e-05  8e-15
#  7: -5.0143e+02 -5.0716e+02  6e+00  3e-13  9e-15
#  8: -5.0278e+02 -5.0408e+02  1e+00  7e-13  8e-15
#  9: -5.0315e+02 -5.0328e+02  1e-01  8e-13  9e-15
# 10: -5.0319e+02 -5.0320e+02  4e-03  2e-13  8e-15
# 11: -5.0319e+02 -5.0319e+02  7e-05  6e-13  9e-15
# Optimal solution found.
# Gaussian Solved for  3  &  6  in  26.068931579589844 s
# Done for batch  26  in  32.87038540840149
# Going for batch  27
# Kernel Computed for  3  &  7  in  6.297285318374634 s
#      pcost       dcost       gap    pres   dres
#  0: -9.2836e+01 -7.1347e+03  3e+04  2e+00  5e-15
#  1: -4.5561e+01 -3.4670e+03  6e+03  2e-01  2e-15
#  2: -6.5966e+00 -7.3664e+02  1e+03  3e-02  6e-15
#  3: -2.9623e+01 -1.6707e+02  2e+02  4e-03  3e-15
#  4: -4.5780e+01 -8.6304e+01  4e+01  9e-04  2e-15
#  5: -5.2466e+01 -6.7231e+01  2e+01  2e-04  2e-15
#  6: -5.5594e+01 -6.0481e+01  5e+00  4e-05  2e-15
#  7: -5.6733e+01 -5.8387e+01  2e+00  6e-06  2e-15
#  8: -5.7241e+01 -5.7533e+01  3e-01  3e-07  2e-15
#  9: -5.7346e+01 -5.7382e+01  4e-02  4e-08  2e-15
# 10: -5.7361e+01 -5.7362e+01  7e-04  3e-10  2e-15
# 11: -5.7361e+01 -5.7361e+01  2e-05  6e-12  2e-15
# Optimal solution found.
# Gaussian Solved for  3  &  7  in  26.024810791015625 s
# Done for batch  27  in  32.80791234970093
# Going for batch  28
# Kernel Computed for  3  &  8  in  6.309227228164673 s
#      pcost       dcost       gap    pres   dres
#  0: -2.2223e+02 -8.4141e+03  4e+04  2e+00  5e-15
#  1: -1.3588e+02 -4.6583e+03  8e+03  3e-01  3e-15
#  2: -8.2884e+01 -1.3246e+03  2e+03  5e-02  4e-15
#  3: -1.3866e+02 -4.3341e+02  3e+02  8e-03  3e-15
#  4: -1.6992e+02 -2.3917e+02  7e+01  1e-03  2e-15
#  5: -1.8157e+02 -2.0218e+02  2e+01  2e-04  2e-15
#  6: -1.8572e+02 -1.9211e+02  6e+00  5e-05  2e-15
#  7: -1.8735e+02 -1.8861e+02  1e+00  4e-06  2e-15
#  8: -1.8774e+02 -1.8789e+02  1e-01  3e-07  2e-15
#  9: -1.8779e+02 -1.8780e+02  5e-03  8e-09  2e-15
# 10: -1.8779e+02 -1.8779e+02  1e-04  1e-10  2e-15
# Optimal solution found.
# Gaussian Solved for  3  &  8  in  23.881210327148438 s
# Done for batch  28  in  30.678987503051758
# Going for batch  29
# Kernel Computed for  3  &  9  in  6.321650266647339 s
#      pcost       dcost       gap    pres   dres
#  0: -1.1714e+02 -7.2200e+03  3e+04  2e+00  5e-15
#  1: -5.7504e+01 -3.5569e+03  6e+03  2e-01  2e-15
#  2: -2.3175e+01 -6.8503e+02  8e+02  2e-02  4e-15
#  3: -6.5374e+01 -1.7868e+02  1e+02  3e-03  3e-15
#  4: -8.2099e+01 -1.1645e+02  4e+01  6e-04  2e-15
#  5: -8.8468e+01 -1.0144e+02  1e+01  1e-04  2e-15
#  6: -9.1379e+01 -9.5512e+01  4e+00  1e-05  1e-15
#  7: -9.2466e+01 -9.3422e+01  1e+00  1e-06  1e-15
#  8: -9.2761e+01 -9.2921e+01  2e-01  9e-08  1e-15
#  9: -9.2821e+01 -9.2827e+01  6e-03  2e-09  2e-15
# 10: -9.2823e+01 -9.2823e+01  1e-04  4e-11  2e-15
# 11: -9.2823e+01 -9.2823e+01  3e-06  7e-13  2e-15
# Optimal solution found.
# Gaussian Solved for  3  &  9  in  26.06284236907959 s
# Done for batch  29  in  32.87054109573364
# Going for batch  30
# Kernel Computed for  4  &  5  in  6.326574802398682 s
#      pcost       dcost       gap    pres   dres
#  0: -1.5598e+02 -6.9927e+03  3e+04  2e+00  5e-15
#  1: -8.8657e+01 -3.4857e+03  6e+03  2e-01  2e-15
#  2: -5.9446e+01 -7.3609e+02  8e+02  2e-02  4e-15
#  3: -1.0523e+02 -2.6151e+02  2e+02  4e-03  3e-15
#  4: -1.2171e+02 -1.8069e+02  6e+01  1e-03  2e-15
#  5: -1.2850e+02 -1.5673e+02  3e+01  7e-14  2e-15
#  6: -1.3314e+02 -1.4204e+02  9e+00  2e-13  2e-15
#  7: -1.3446e+02 -1.3849e+02  4e+00  7e-14  2e-15
#  8: -1.3538e+02 -1.3651e+02  1e+00  2e-13  2e-15
#  9: -1.3573e+02 -1.3581e+02  8e-02  9e-14  2e-15
# 10: -1.3576e+02 -1.3576e+02  2e-03  2e-13  2e-15
# 11: -1.3576e+02 -1.3576e+02  6e-05  2e-13  2e-15
# Optimal solution found.
# Gaussian Solved for  4  &  5  in  26.078190803527832 s
# Done for batch  30  in  32.89657497406006
# Going for batch  31
# Kernel Computed for  4  &  6  in  6.313436508178711 s
#      pcost       dcost       gap    pres   dres
#  0: -8.9772e+02 -9.6565e+03  4e+04  2e+00  1e-14
#  1: -7.1427e+02 -5.9961e+03  8e+03  2e-01  2e-14
#  2: -7.5707e+02 -1.7361e+03  1e+03  3e-02  2e-14
#  3: -8.6971e+02 -1.1390e+03  3e+02  5e-03  2e-14
#  4: -9.1628e+02 -1.0034e+03  9e+01  7e-04  2e-14
#  5: -9.3428e+02 -9.5281e+02  2e+01  8e-05  2e-14
#  6: -9.3898e+02 -9.4171e+02  3e+00  8e-06  2e-14
#  7: -9.3981e+02 -9.3998e+02  2e-01  4e-07  2e-14
#  8: -9.3987e+02 -9.3987e+02  7e-03  1e-08  2e-14
#  9: -9.3987e+02 -9.3987e+02  2e-04  2e-10  2e-14
# Optimal solution found.
# Gaussian Solved for  4  &  6  in  21.68860149383545 s
# Done for batch  31  in  28.492288827896118
# Going for batch  32
# Kernel Computed for  4  &  7  in  6.36040997505188 s
#      pcost       dcost       gap    pres   dres
#  0: -9.3076e+01 -7.2188e+03  3e+04  2e+00  5e-15
#  1: -4.4606e+01 -3.5557e+03  6e+03  2e-01  2e-15
#  2: -6.2621e+00 -7.8910e+02  1e+03  4e-02  8e-15
#  3: -3.2395e+01 -1.7430e+02  2e+02  4e-03  3e-15
#  4: -4.9879e+01 -9.0250e+01  4e+01  8e-04  2e-15
#  5: -5.7061e+01 -7.1118e+01  1e+01  1e-04  2e-15
#  6: -6.0160e+01 -6.4483e+01  4e+00  1e-05  2e-15
#  7: -6.1222e+01 -6.2514e+01  1e+00  3e-06  2e-15
#  8: -6.1633e+01 -6.1812e+01  2e-01  7e-14  2e-15
#  9: -6.1706e+01 -6.1711e+01  5e-03  3e-14  2e-15
# 10: -6.1709e+01 -6.1709e+01  9e-05  3e-14  2e-15
# 11: -6.1709e+01 -6.1709e+01  2e-06  1e-14  2e-15
# Optimal solution found.
# Gaussian Solved for  4  &  7  in  26.018897533416748 s
# Done for batch  32  in  32.86519479751587
# Going for batch  33
# Kernel Computed for  4  &  8  in  6.306724786758423 s
#      pcost       dcost       gap    pres   dres
#  0: -2.2465e+02 -6.8855e+03  3e+04  2e+00  5e-15
#  1: -1.4528e+02 -3.4652e+03  5e+03  2e-01  2e-15
#  2: -1.2473e+02 -7.6671e+02  8e+02  2e-02  3e-15
#  3: -1.7986e+02 -3.1703e+02  1e+02  3e-03  3e-15
#  4: -1.9975e+02 -2.3811e+02  4e+01  6e-04  2e-15
#  5: -2.0764e+02 -2.1714e+02  1e+01  9e-05  2e-15
#  6: -2.1013e+02 -2.1205e+02  2e+00  1e-05  2e-15
#  7: -2.1073e+02 -2.1097e+02  2e-01  7e-07  2e-15
#  8: -2.1081e+02 -2.1082e+02  1e-02  3e-08  2e-15
#  9: -2.1082e+02 -2.1082e+02  3e-04  6e-10  2e-15
# 10: -2.1082e+02 -2.1082e+02  6e-06  7e-12  2e-15
# Optimal solution found.
# Gaussian Solved for  4  &  8  in  23.8243088722229 s
# Done for batch  33  in  30.614717483520508
# Going for batch  34
# Kernel Computed for  4  &  9  in  6.284932374954224 s
#      pcost       dcost       gap    pres   dres
#  0: -1.1407e+02 -6.5885e+03  3e+04  2e+00  4e-15
#  1: -5.4731e+01 -3.0743e+03  5e+03  2e-01  2e-15
#  2: -3.3614e+01 -5.3901e+02  6e+02  2e-02  5e-15
#  3: -7.3851e+01 -1.8900e+02  1e+02  3e-03  3e-15
#  4: -8.8826e+01 -1.2601e+02  4e+01  7e-04  2e-15
#  5: -9.4967e+01 -1.0838e+02  1e+01  2e-04  2e-15
#  6: -9.7972e+01 -1.0158e+02  4e+00  2e-05  1e-15
#  7: -9.8948e+01 -9.9746e+01  8e-01  2e-06  1e-15
#  8: -9.9202e+01 -9.9319e+01  1e-01  2e-07  1e-15
#  9: -9.9246e+01 -9.9249e+01  3e-03  3e-09  2e-15
# 10: -9.9248e+01 -9.9248e+01  7e-05  7e-11  2e-15
# Optimal solution found.
# Gaussian Solved for  4  &  9  in  24.183074474334717 s
# Done for batch  34  in  30.95112895965576
# Going for batch  35
# Kernel Computed for  5  &  6  in  6.298571825027466 s
#      pcost       dcost       gap    pres   dres
#  0: -2.0533e+02 -7.5506e+03  3e+04  2e+00  5e-15
#  1: -1.2813e+02 -3.9857e+03  6e+03  2e-01  3e-15
#  2: -9.5987e+01 -7.8644e+02  8e+02  2e-02  6e-15
#  3: -1.4760e+02 -3.3431e+02  2e+02  5e-03  3e-15
#  4: -1.6699e+02 -2.3327e+02  7e+01  1e-03  2e-15
#  5: -1.7565e+02 -2.0037e+02  3e+01  2e-04  2e-15
#  6: -1.7993e+02 -1.8778e+02  8e+00  3e-05  2e-15
#  7: -1.8146e+02 -1.8393e+02  2e+00  2e-13  2e-15
#  8: -1.8213e+02 -1.8255e+02  4e-01  2e-13  2e-15
#  9: -1.8227e+02 -1.8229e+02  3e-02  4e-14  2e-15
# 10: -1.8228e+02 -1.8228e+02  4e-04  7e-14  2e-15
# 11: -1.8228e+02 -1.8228e+02  7e-06  4e-14  2e-15
# Optimal solution found.
# Gaussian Solved for  5  &  6  in  26.126487493515015 s
# Done for batch  35  in  32.91132998466492
# Going for batch  36
# Kernel Computed for  5  &  7  in  6.32495641708374 s
#      pcost       dcost       gap    pres   dres
#  0: -3.7910e+02 -8.4574e+03  4e+04  2e+00  1e-14
#  1: -2.7286e+02 -4.7996e+03  8e+03  3e-01  1e-14
#  2: -2.3217e+02 -1.1233e+03  1e+03  2e-02  1e-14
#  3: -3.0157e+02 -5.9118e+02  3e+02  6e-03  1e-14
#  4: -3.3486e+02 -4.4665e+02  1e+02  1e-03  1e-14
#  5: -3.5167e+02 -3.9013e+02  4e+01  3e-04  1e-14
#  6: -3.5933e+02 -3.6849e+02  9e+00  2e-05  1e-14
#  7: -3.6174e+02 -3.6303e+02  1e+00  6e-07  1e-14
#  8: -3.6215e+02 -3.6228e+02  1e-01  5e-08  1e-14
#  9: -3.6219e+02 -3.6220e+02  5e-03  1e-09  1e-14
# 10: -3.6219e+02 -3.6219e+02  9e-05  2e-11  1e-14
# Optimal solution found.
# Gaussian Solved for  5  &  7  in  23.841464042663574 s
# Done for batch  36  in  30.65290379524231
# Going for batch  37
# Kernel Computed for  5  &  8  in  6.315456390380859 s
#      pcost       dcost       gap    pres   dres
#  0: -2.5877e+02 -7.3164e+03  3e+04  2e+00  5e-15
#  1: -1.6844e+02 -3.8401e+03  5e+03  2e-01  3e-15
#  2: -1.7506e+02 -7.0557e+02  6e+02  1e-02  6e-15
#  3: -2.3098e+02 -3.8532e+02  2e+02  3e-03  3e-15
#  4: -2.5075e+02 -3.0061e+02  5e+01  6e-04  2e-15
#  5: -2.5761e+02 -2.7802e+02  2e+01  2e-04  2e-15
#  6: -2.6136e+02 -2.6687e+02  6e+00  1e-05  2e-15
#  7: -2.6251e+02 -2.6379e+02  1e+00  1e-13  2e-15
#  8: -2.6285e+02 -2.6299e+02  1e-01  3e-13  2e-15
#  9: -2.6289e+02 -2.6290e+02  5e-03  6e-13  2e-15
# 10: -2.6290e+02 -2.6290e+02  1e-04  2e-13  2e-15
# Optimal solution found.
# Gaussian Solved for  5  &  8  in  23.83626890182495 s
# Done for batch  37  in  30.635283946990967
# Going for batch  38
# Kernel Computed for  5  &  9  in  6.313492774963379 s
#      pcost       dcost       gap    pres   dres
#  0: -2.7302e+02 -7.5652e+03  3e+04  2e+00  6e-15
#  1: -1.9616e+02 -4.0285e+03  6e+03  2e-01  4e-15
#  2: -1.7674e+02 -7.9849e+02  7e+02  2e-02  6e-15
#  3: -2.2908e+02 -4.2790e+02  2e+02  4e-03  4e-15
#  4: -2.5164e+02 -3.1447e+02  6e+01  7e-04  3e-15
#  5: -2.6163e+02 -2.8082e+02  2e+01  2e-05  3e-15
#  6: -2.6538e+02 -2.6993e+02  5e+00  7e-07  3e-15
#  7: -2.6630e+02 -2.6772e+02  1e+00  1e-14  3e-15
#  8: -2.6665e+02 -2.6698e+02  3e-01  4e-14  3e-15
#  9: -2.6674e+02 -2.6679e+02  5e-02  4e-13  3e-15
# 10: -2.6676e+02 -2.6676e+02  1e-03  2e-13  3e-15
# 11: -2.6676e+02 -2.6676e+02  1e-05  3e-13  3e-15
# Optimal solution found.
# Gaussian Solved for  5  &  9  in  26.059818029403687 s
# Done for batch  38  in  32.85895490646362
# Going for batch  39
# Kernel Computed for  6  &  7  in  6.299336194992065 s
#      pcost       dcost       gap    pres   dres
#  0: -1.1028e+02 -7.5103e+03  4e+04  2e+00  5e-15
#  1: -5.6897e+01 -3.8143e+03  7e+03  3e-01  3e-15
#  2: -1.3830e+01 -9.2363e+02  1e+03  4e-02  7e-15
#  3: -3.9528e+01 -1.9616e+02  2e+02  4e-03  4e-15
#  4: -5.5680e+01 -1.2195e+02  7e+01  2e-03  3e-15
#  5: -6.4887e+01 -8.8241e+01  2e+01  1e-04  2e-15
#  6: -6.9418e+01 -7.6829e+01  7e+00  2e-05  2e-15
#  7: -7.1201e+01 -7.3118e+01  2e+00  2e-06  2e-15
#  8: -7.1797e+01 -7.2062e+01  3e-01  1e-07  2e-15
#  9: -7.1900e+01 -7.1908e+01  8e-03  2e-09  2e-15
# 10: -7.1903e+01 -7.1903e+01  1e-04  3e-11  2e-15
# 11: -7.1903e+01 -7.1903e+01  2e-06  3e-13  2e-15
# Optimal solution found.
# Gaussian Solved for  6  &  7  in  26.116963863372803 s
# Done for batch  39  in  32.8997163772583
# Going for batch  40
# Kernel Computed for  6  &  8  in  6.324477910995483 s
#      pcost       dcost       gap    pres   dres
#  0: -3.3801e+02 -8.0319e+03  4e+04  2e+00  5e-15
#  1: -2.4315e+02 -4.4272e+03  7e+03  2e-01  3e-15
#  2: -2.2086e+02 -9.6970e+02  9e+02  2e-02  5e-15
#  3: -2.8364e+02 -5.1393e+02  2e+02  5e-03  3e-15
#  4: -3.1190e+02 -3.6929e+02  6e+01  3e-04  3e-15
#  5: -3.2242e+02 -3.3848e+02  2e+01  4e-05  2e-15
#  6: -3.2587e+02 -3.2978e+02  4e+00  6e-06  2e-15
#  7: -3.2693e+02 -3.2738e+02  4e-01  4e-07  2e-15
#  8: -3.2708e+02 -3.2710e+02  2e-02  1e-08  3e-15
#  9: -3.2708e+02 -3.2709e+02  5e-04  2e-10  3e-15
# 10: -3.2708e+02 -3.2708e+02  1e-05  3e-12  3e-15
# Optimal solution found.
# Gaussian Solved for  6  &  8  in  23.83267307281494 s
# Done for batch  40  in  30.645123720169067
# Going for batch  41
# Kernel Computed for  6  &  9  in  6.320991277694702 s
#      pcost       dcost       gap    pres   dres
#  0: -1.3972e+02 -6.9017e+03  3e+04  2e+00  5e-15
#  1: -7.4093e+01 -3.3717e+03  5e+03  2e-01  2e-15
#  2: -4.9322e+01 -5.8506e+02  6e+02  2e-02  5e-15
#  3: -9.5462e+01 -2.0704e+02  1e+02  3e-03  3e-15
#  4: -1.1120e+02 -1.4547e+02  4e+01  6e-04  2e-15
#  5: -1.1785e+02 -1.2868e+02  1e+01  6e-05  2e-15
#  6: -1.2042e+02 -1.2319e+02  3e+00  8e-06  2e-15
#  7: -1.2125e+02 -1.2164e+02  4e-01  4e-07  2e-15
#  8: -1.2138e+02 -1.2141e+02  2e-02  7e-09  2e-15
#  9: -1.2139e+02 -1.2139e+02  7e-04  2e-10  2e-15
# 10: -1.2139e+02 -1.2139e+02  1e-05  3e-12  2e-15
# Optimal solution found.
# Gaussian Solved for  6  &  9  in  23.840190172195435 s
# Done for batch  41  in  30.646297693252563
# Going for batch  42
# Kernel Computed for  7  &  8  in  6.315353155136108 s
#      pcost       dcost       gap    pres   dres
#  0: -1.4021e+02 -7.5807e+03  4e+04  2e+00  5e-15
#  1: -7.7474e+01 -3.9413e+03  7e+03  3e-01  3e-15
#  2: -3.7302e+01 -1.0367e+03  1e+03  4e-02  4e-15
#  3: -7.4177e+01 -2.7628e+02  2e+02  6e-03  4e-15
#  4: -9.3886e+01 -1.5833e+02  7e+01  1e-03  3e-15
#  5: -1.0307e+02 -1.2356e+02  2e+01  3e-04  2e-15
#  6: -1.0675e+02 -1.1333e+02  7e+00  5e-05  2e-15
#  7: -1.0821e+02 -1.0986e+02  2e+00  6e-06  2e-15
#  8: -1.0865e+02 -1.0897e+02  3e-01  7e-07  2e-15
#  9: -1.0875e+02 -1.0879e+02  4e-02  6e-08  2e-15
# 10: -1.0876e+02 -1.0876e+02  1e-03  1e-09  2e-15
# 11: -1.0876e+02 -1.0876e+02  2e-05  2e-11  2e-15
# Optimal solution found.
# Gaussian Solved for  7  &  8  in  26.05207371711731 s
# Done for batch  42  in  32.85229468345642
# Going for batch  43
# Kernel Computed for  7  &  9  in  6.309123992919922 s
#      pcost       dcost       gap    pres   dres
#  0: -3.8746e+02 -9.5957e+03  5e+04  3e+00  8e-15
#  1: -2.8432e+02 -5.5742e+03  9e+03  3e-01  9e-15
#  2: -2.5152e+02 -1.4261e+03  1e+03  3e-02  9e-15
#  3: -3.0818e+02 -7.0514e+02  4e+02  9e-03  8e-15
#  4: -3.4189e+02 -4.9364e+02  2e+02  2e-03  9e-15
#  5: -3.5935e+02 -4.1679e+02  6e+01  4e-04  9e-15
#  6: -3.6813e+02 -3.8647e+02  2e+01  2e-13  1e-14
#  7: -3.7153e+02 -3.7782e+02  6e+00  3e-14  9e-15
#  8: -3.7293e+02 -3.7451e+02  2e+00  5e-13  1e-14
#  9: -3.7345e+02 -3.7358e+02  1e-01  7e-13  1e-14
# 10: -3.7350e+02 -3.7350e+02  4e-03  1e-13  1e-14
# 11: -3.7350e+02 -3.7350e+02  8e-05  1e-13  1e-14
# Optimal solution found.
# Gaussian Solved for  7  &  9  in  26.133774518966675 s
# Done for batch  43  in  32.92958974838257
# Going for batch  44
# Kernel Computed for  8  &  9  in  6.3657121658325195 s
#      pcost       dcost       gap    pres   dres
#  0: -1.5990e+02 -7.2285e+03  3e+04  2e+00  5e-15
#  1: -7.8001e+01 -3.7404e+03  6e+03  2e-01  2e-15
#  2: -5.8062e+01 -7.5437e+02  8e+02  2e-02  6e-15
#  3: -1.2171e+02 -2.6113e+02  1e+02  3e-03  3e-15
#  4: -1.4164e+02 -1.8153e+02  4e+01  6e-04  2e-15
#  5: -1.4951e+02 -1.6040e+02  1e+01  6e-05  2e-15
#  6: -1.5210e+02 -1.5479e+02  3e+00  8e-06  2e-15
#  7: -1.5284e+02 -1.5330e+02  5e-01  9e-07  2e-15
#  8: -1.5299e+02 -1.5303e+02  4e-02  5e-08  2e-15
#  9: -1.5300e+02 -1.5301e+02  7e-04  8e-10  2e-15
# 10: -1.5300e+02 -1.5300e+02  1e-05  1e-11  2e-15
# Optimal solution found.
# Gaussian Solved for  8  &  9  in  24.97056555747986 s
# Done for batch  44  in  31.843292236328125
# One vs One Done in  1476.5895144939423 s

# %%
#Saving the learnt values of alphas for all the 45 classifiers for future use
f = "alpha_b_ovo.csv"
f = open(f,"w")
count = 0
for i in range(len(alphas)):
    alpha, d, dp = alphas[i]
    alpha = ",".join(alpha.flatten().astype("str"))
    alpha = str(d),str(dp),str(b[d][dp]),alpha
    alpha = ",".join(alpha)
    f.write(alpha+"\n")

# %%
#Importing Validation and testing data
s = time.time()

data_val = pd.read_csv('../fashion_mnist/val.csv', header=None)
data_val = data_val.to_numpy()

data_test = pd.read_csv('../fashion_mnist/test.csv', header=None)
data_test = data_test.to_numpy()

y_val = data_val[:,-1]
y_test = data_test[:,-1]

data_val = data_val[:,:-1]
data_test = data_test[:,:-1]

data_val /= 255
data_test /= 255
print("Validation and Test Data imported in: ", time.time()-s, "s")
# Out:
# Validation and Test Data imported in:  3.3152167797088623 s

# %%
#Function to predict classes of test set, using One vs One Classifier technique
def prediction(alphas, b, test):
    n_test = test.shape[0]
    scores = np.zeros((n_test, 10))
    votes = np.zeros((n_test, 10))
    
    for i in alphas:
        s = time.time()
        alpha, d, dp = i
        
        count_d, count_dp, data_d_dp = extract_data(d, dp)
        data_d_dp /= 255

        y_d = np.full(count_d, -1).reshape(-1,1)
        y_dp = np.full(count_dp, 1).reshape(-1,1)

        y = np.concatenate((y_d, y_dp), axis = 0)
        y_d = []
        y_dp = []
        alpha_y = (y * alpha)
        
        pred = cdist(data_d_dp, test)
        pred = np.exp(-gamma*np.square(pred))
        pred = np.sum(np.multiply(pred, alpha_y), axis = 0)  + b[d][dp]
        
        index_d = np.argwhere(pred<0).flatten()
        index_dp = np.argwhere(pred>=0).flatten()
        
        votes[index_d,d] += 1
        votes[index_dp,dp] += 1
        
        scores[index_d,d] += abs(pred[index_d])
        scores[index_dp,dp] += abs(pred[index_dp])
        print("Done for ",d,"&",dp,"in :", time.time()-s)
        
        
        
        
    class_pred = []
    for i in range(n_test):
        vote = votes[i]
        winner = np.argwhere(vote == np.max(vote))
        if(winner.shape[0]>1):
            winner = winner.flatten()
            score = scores[i]
            won = np.argwhere(score == np.max(score[winner]))
            class_pred.append(won[0][0])
        else:
            class_pred.append(winner[0][0])
            
    return class_pred

# %%
#Accuracy over a given preediction set and set of actual labels
def accuracy(pred, y):
    confusion = np.zeros((10, 10))
    count = 0
    for i in range(len(y)):
        confusion[int(pred[i]), int(y[i])] += 1
        if(pred[i]==y[i]):
            count += 1
    return count*100/(len(y)), confusion

# %%
#Accuracy over validation set in our implementation
s = time.time()
pred_val = prediction(alphas, b, data_val)
print("Time taken to predict Validation set is: ", time.time()-s)
acc_val, confusion_val = accuracy(pred_val, y_val)
print("Accuarcy over validation set in multi class classification is: ", acc_val, "%")

# %%
#Accuracy over test set in our implementation
s = time.time()
pred_test = prediction(alphas, b, data_test)
print("Time taken to predict test set is: ", time.time()-s)
acc_test, confusion_test = accuracy(pred_test, y_test)
print("Accuarcy over test set in multi class classification is: ", acc_test, "%")
# Out:
# Done for  0 & 1 in : 15.68754768371582
# Done for  0 & 2 in : 15.397441148757935
# Done for  0 & 3 in : 15.536777973175049
# Done for  0 & 4 in : 15.56071400642395
# Done for  0 & 5 in : 15.597939014434814
# Done for  0 & 6 in : 15.628666162490845
# Done for  0 & 7 in : 15.50343918800354
# Done for  0 & 8 in : 15.507837533950806
# Done for  0 & 9 in : 15.481278896331787
# Done for  1 & 2 in : 15.854492425918579
# Done for  1 & 3 in : 15.53148078918457
# Done for  1 & 4 in : 15.532623052597046
# Done for  1 & 5 in : 15.86173677444458
# Done for  1 & 6 in : 15.804723262786865
# Done for  1 & 7 in : 15.762629508972168
# Done for  1 & 8 in : 15.569353580474854
# Done for  1 & 9 in : 15.818818092346191
# Done for  2 & 3 in : 15.585557222366333
# Done for  2 & 4 in : 15.48154616355896
# Done for  2 & 5 in : 15.728162288665771
# Done for  2 & 6 in : 15.538205862045288
# Done for  2 & 7 in : 15.805870532989502
# Done for  2 & 8 in : 15.765530347824097
# Done for  2 & 9 in : 15.246947050094604
# Done for  3 & 4 in : 15.53453278541565
# Done for  3 & 5 in : 15.629666566848755
# Done for  3 & 6 in : 16.087675094604492
# Done for  3 & 7 in : 15.947230100631714
# Done for  3 & 8 in : 15.950631380081177
# Done for  3 & 9 in : 16.17155122756958
# Done for  4 & 5 in : 15.724926471710205
# Done for  4 & 6 in : 16.013784885406494
# Done for  4 & 7 in : 15.938329219818115
# Done for  4 & 8 in : 15.509809970855713
# Done for  4 & 9 in : 15.45126986503601
# Done for  5 & 6 in : 15.842541694641113
# Done for  5 & 7 in : 15.88003396987915
# Done for  5 & 8 in : 16.60970139503479
# Done for  5 & 9 in : 16.154314517974854
# Done for  6 & 7 in : 16.159380197525024
# Done for  6 & 8 in : 15.633495807647705
# Done for  6 & 9 in : 15.469638347625732
# Done for  7 & 8 in : 15.98321795463562
# Done for  7 & 9 in : 15.958582639694214
# Done for  8 & 9 in : 16.48985719680786
# Time taken to predict test set is:  709.028838634491
# Accuarcy over test set in multi class classification is:  85.08 %

# %%
#Confusion matrix for test and validation set in our implementation
print("The confusion matrix for validation set is:\n", confusion_val,"\n")
print("The confusion matrix for test set is:\n", confusion_test)
# Out:
# The confusion matrix for validation set is:
#  [[201.   0.   2.  11.   0.   0.  19.   0.   0.   0.]
#  [  2. 240.   0.   7.   2.   0.   0.   0.   0.   0.]
#  [  1.   2. 208.   0.  30.   0.  27.   0.   1.   0.]
#  [  4.   2.   1. 197.   5.   1.   1.   0.   0.   0.]
#  [  0.   0.  13.   6. 185.   0.  11.   0.   0.   0.]
#  [  0.   0.   0.   0.   0. 226.   0.  24.   0.   2.]
#  [ 38.   3.  14.  20.  19.   0. 184.   0.   2.   0.]
#  [  0.   0.   0.   0.   0.   1.   0. 199.   2.   4.]
#  [  4.   3.  12.   9.   9.  16.   8.   6. 245.   5.]
#  [  0.   0.   0.   0.   0.   6.   0.  21.   0. 239.]]
#
# The confusion matrix for test set is:
#  [[404.   0.   0.  17.   0.   1.  52.   0.   1.   0.]
#  [  0. 484.   0.  10.   1.   0.   1.   0.   0.   0.]
#  [  7.   6. 414.   2.  55.   0.  52.   0.   1.   0.]
#  [  7.   2.   3. 410.  12.   0.   5.   0.   0.   0.]
#  [  0.   0.  26.   6. 366.   0.  20.   0.   0.   0.]
#  [  0.   0.   0.   0.   0. 432.   0.  48.   0.   5.]
#  [ 65.   6.  44.  39.  51.   0. 351.   0.   3.   0.]
#  [  0.   0.   0.   0.   0.   7.   0. 411.   0.   6.]
#  [ 17.   2.  13.  16.  15.  48.  19.   6. 495.   2.]
#  [  0.   0.   0.   0.   0.  12.   0.  35.   0. 487.]]

# %%
#Enumerating the desired models of binary classifiers
n=10
ids = []
for i in range(n):
    for j in range(i+1, n):
        ids.append((i,j))
        
#One vs One SVM Sklearn
#Training 45 different models of binary classifiers using Sklearn library
batchsize = 1
clfs = []
s1 = time.time()
for i in range(int(45/batchsize)):
    
    print("Going for batch ", i)
    
    s = time.time()
    for j in range(batchsize):
        
        d, dp = ids[i*batchsize + j]
        count_d, count_dp, data_d_dp = extract_data(d, dp)
        data_d_dp /= 255

        y_d = np.full(count_d, -1).reshape(-1,1)
        y_dp = np.full(count_dp, 1).reshape(-1,1)

        y = np.concatenate((y_d, y_dp), axis = 0)
        y_d = []
        y_dp = []
        
        clf = SVC(kernel='rbf',gamma=0.05)
        clf.fit(data_d_dp, y.flatten())
        
        clfs.append((clf,d,dp))
    print("Done for batch ", i, " in ", time.time()-s)
print("One vs One SKlearn Done in ", time.time()-s1, "s")
# Out:
# Going for batch  0
# Done for batch  0  in  4.757843494415283
# Going for batch  1
# Done for batch  1  in  7.285531520843506
# Going for batch  2
# Done for batch  2  in  8.868611097335815
# Going for batch  3
# Done for batch  3  in  6.176299333572388
# Going for batch  4
# Done for batch  4  in  5.466998338699341
# Going for batch  5
# Done for batch  5  in  12.802596092224121
# Going for batch  6
# Done for batch  6  in  3.223029851913452
# Going for batch  7
# Done for batch  7  in  7.0697338581085205
# Going for batch  8
# Done for batch  8  in  4.445237159729004
# Going for batch  9
# Done for batch  9  in  4.551787614822388
# Going for batch  10
# Done for batch  10  in  5.24731183052063
# Going for batch  11
# Done for batch  11  in  4.1707375049591064
# Going for batch  12
# Done for batch  12  in  4.582836627960205
# Going for batch  13
# Done for batch  13  in  5.614081859588623
# Going for batch  14
# Done for batch  14  in  2.219125270843506
# Going for batch  15
# Done for batch  15  in  5.326971769332886
# Going for batch  16
# Done for batch  16  in  3.8198466300964355
# Going for batch  17
# Done for batch  17  in  6.081094980239868
# Going for batch  18
# Done for batch  18  in  12.932369470596313
# Going for batch  19
# Done for batch  19  in  5.745820760726929
# Going for batch  20
# Done for batch  20  in  13.734702587127686
# Going for batch  21
# Done for batch  21  in  3.3477470874786377
# Going for batch  22
# Done for batch  22  in  7.674453496932983
# Going for batch  23
# Done for batch  23  in  4.864276647567749
# Going for batch  24
# Done for batch  24  in  6.906070947647095
# Going for batch  25
# Done for batch  25  in  5.360506772994995
# Going for batch  26
# Done for batch  26  in  9.442102670669556
# Going for batch  27
# Done for batch  27  in  3.124082326889038
# Going for batch  28
# Done for batch  28  in  7.156752586364746
# Going for batch  29
# Done for batch  29  in  4.183517932891846
# Going for batch  30
# Done for batch  30  in  5.3578410148620605
# Going for batch  31
# Done for batch  31  in  14.050787210464478
# Going for batch  32
# Done for batch  32  in  3.303936004638672
# Going for batch  33
# Done for batch  33  in  7.570484161376953
# Going for batch  34
# Done for batch  34  in  4.3459954261779785
# Going for batch  35
# Done for batch  35  in  6.021634101867676
# Going for batch  36
# Done for batch  36  in  7.6984875202178955
# Going for batch  37
# Done for batch  37  in  8.298342227935791
# Going for batch  38
# Done for batch  38  in  7.209751844406128
# Going for batch  39
# Done for batch  39  in  4.12148904800415
# Going for batch  40
# Done for batch  40  in  8.578912258148193
# Going for batch  41
# Done for batch  41  in  4.987179517745972
# Going for batch  42
# Done for batch  42  in  5.621052503585815
# Going for batch  43
# Done for batch  43  in  6.973859786987305
# Going for batch  44
# Done for batch  44  in  7.442530155181885
# One vs One SKlearn Done in  287.775963306427 s

# %%
#Function to predict classes of test set, using One vs One Classifier technique in all the 45 classifiers
def prediction_sklearn(clfs, test):
    n_test = test.shape[0]
    scores = np.zeros((n_test, 10))
    votes = np.zeros((n_test, 10))
    
    for i in clfs:
        s = time.time()
        clf, d, dp = i
        
        pred = clf.decision_function(test)
        index_d = np.argwhere(pred<0).flatten()
        index_dp = np.argwhere(pred>=0).flatten()
        
        votes[index_d,d] += 1
        votes[index_dp,dp] += 1
        
        scores[index_d,d] += abs(pred[index_d])
        scores[index_dp,dp] += abs(pred[index_dp])
        print("Done for ",d,"&",dp,"in :", time.time()-s)
        
        
        
        
    class_pred = []
    for i in range(n_test):
        vote = votes[i]
        winner = np.argwhere(vote == np.max(vote))
        if(winner.shape[0]>1):
            winner = winner.flatten()
            score = scores[i]
            won = np.argwhere(score == np.max(score[winner]))
            class_pred.append(won[0][0])
        else:
            class_pred.append(winner[0][0])
            
    return class_pred

# %%
#Accuracy over validation set in Sklearn implementation
s = time.time()
pred_val_sklearn = prediction_sklearn(clfs, data_val)
print("Time taken to predict Validation set is: ", time.time()-s)
acc_val_sklearn, confusion_val_sklearn = accuracy(pred_val_sklearn, y_val)
print("Accuarcy over validation set in multi class classification is: ", acc_val_sklearn, "%")
# Out:
# Done for  0 & 1 in : 2.050034284591675
# Done for  0 & 2 in : 3.76025390625
# Done for  0 & 3 in : 4.47006893157959
# Done for  0 & 4 in : 3.561756134033203
# Done for  0 & 5 in : 3.1371910572052
# Done for  0 & 6 in : 7.312145948410034
# Done for  0 & 7 in : 1.5327484607696533
# Done for  0 & 8 in : 3.8217577934265137
# Done for  0 & 9 in : 2.220465898513794
# Done for  1 & 2 in : 2.0789496898651123
# Done for  1 & 3 in : 2.452998161315918
# Done for  1 & 4 in : 1.8658175468444824
# Done for  1 & 5 in : 1.9528255462646484
# Done for  1 & 6 in : 2.4247355461120605
# Done for  1 & 7 in : 0.9813377857208252
# Done for  1 & 8 in : 2.6858839988708496
# Done for  1 & 9 in : 1.6202025413513184
# Done for  2 & 3 in : 3.161393880844116
# Done for  2 & 4 in : 6.843564987182617
# Done for  2 & 5 in : 2.85433030128479
# Done for  2 & 6 in : 7.379079818725586
# Done for  2 & 7 in : 1.548896074295044
# Done for  2 & 8 in : 4.248725175857544
# Done for  2 & 9 in : 2.5789008140563965
# Done for  3 & 4 in : 4.2903454303741455
# Done for  3 & 5 in : 2.6840145587921143
# Done for  3 & 6 in : 5.39546012878418
# Done for  3 & 7 in : 1.4710285663604736
# Done for  3 & 8 in : 3.564506769180298
# Done for  3 & 9 in : 1.9196224212646484
# Done for  4 & 5 in : 2.725921869277954
# Done for  4 & 6 in : 7.410151958465576
# Done for  4 & 7 in : 1.553893804550171
# Done for  4 & 8 in : 3.8429105281829834
# Done for  4 & 9 in : 2.1200408935546875
# Done for  5 & 6 in : 3.2556416988372803
# Done for  5 & 7 in : 4.185041189193726
# Done for  5 & 8 in : 4.465108633041382
# Done for  5 & 9 in : 3.9088144302368164
# Done for  6 & 7 in : 1.734673023223877
# Done for  6 & 8 in : 4.568810939788818
# Done for  6 & 9 in : 2.4368772506713867
# Done for  7 & 8 in : 2.930335760116577
# Done for  7 & 9 in : 3.5445001125335693
# Done for  8 & 9 in : 3.5869667530059814
# Time taken to predict Validation set is:  148.21087670326233
# Accuarcy over validation set in multi class classification is:  87.88 %

# %%
#Accuracy over test set in Sklearn implementation
s = time.time()
pred_test_sklearn = prediction_sklearn(clfs, data_test)
print("Time taken to predict test set is: ", time.time()-s)
acc_test_sklearn, confusion_test_sklearn = accuracy(pred_test_sklearn, y_test)
print("Accuarcy over validation set in multi class classification is: ", acc_test_sklearn, "%")
# Out:
# Done for  0 & 1 in : 4.20386266708374
# Done for  0 & 2 in : 7.626614809036255
# Done for  0 & 3 in : 8.920718908309937
# Done for  0 & 4 in : 5.93738579750061
# Done for  0 & 5 in : 5.492050886154175
# Done for  0 & 6 in : 13.585835695266724
# Done for  0 & 7 in : 2.956488609313965
# Done for  0 & 8 in : 7.559519052505493
# Done for  0 & 9 in : 4.095263242721558
# Done for  1 & 2 in : 4.0502769947052
# Done for  1 & 3 in : 5.003556966781616
# Done for  1 & 4 in : 3.7408220767974854
# Done for  1 & 5 in : 3.896029472351074
# Done for  1 & 6 in : 4.800410747528076
# Done for  1 & 7 in : 1.9849026203155518
# Done for  1 & 8 in : 4.938264846801758
# Done for  1 & 9 in : 3.0346572399139404
# Done for  2 & 3 in : 6.11798357963562
# Done for  2 & 4 in : 13.485262870788574
# Done for  2 & 5 in : 5.732669115066528
# Done for  2 & 6 in : 14.648459911346436
# Done for  2 & 7 in : 3.0574026107788086
# Done for  2 & 8 in : 8.11376667022705
# Done for  2 & 9 in : 4.340226650238037
# Done for  3 & 4 in : 7.398317575454712
# Done for  3 & 5 in : 4.8066065311431885
# Done for  3 & 6 in : 9.32892918586731
# Done for  3 & 7 in : 2.550269842147827
# Done for  3 & 8 in : 6.937594175338745
# Done for  3 & 9 in : 4.06053900718689
# Done for  4 & 5 in : 4.964475870132446
# Done for  4 & 6 in : 14.210500478744507
# Done for  4 & 7 in : 3.0114734172821045
# Done for  4 & 8 in : 8.349494218826294
# Done for  4 & 9 in : 4.065008163452148
# Done for  5 & 6 in : 6.296802997589111
# Done for  5 & 7 in : 8.19029450416565
# Done for  5 & 8 in : 8.859772205352783
# Done for  5 & 9 in : 7.682857990264893
# Done for  6 & 7 in : 3.3029186725616455
# Done for  6 & 8 in : 8.98876667022705
# Done for  6 & 9 in : 4.58256196975708
# Done for  7 & 8 in : 5.58552360534668
# Done for  7 & 9 in : 7.087728261947632
# Done for  8 & 9 in : 7.154953718185425
# Time taken to predict Validation set is:  284.8212056159973
# Accuarcy over validation set in multi class classification is:  87.88 %

# %%
#Confusion matrix for test and validation set in Sklearn's implementation
print("The confusion matrix for test set in sklearn is:\n", confusion_val_sklearn,"\n")
print("The confusion matrix for test set in sklearn is:\n", confusion_test_sklearn)
# Out:
# The confusion matrix for validation set in sklearn is:
#  [[212.   0.   5.   6.   1.   0.  33.   0.   0.   0.]
#  [  0. 237.   0.   0.   1.   0.   0.   0.   0.   0.]
#  [  1.   3. 205.   0.  24.   0.  28.   0.   1.   0.]
#  [  8.   7.   3. 228.   8.   1.   4.   0.   1.   0.]
#  [  0.   0.  19.   6. 200.   0.  19.   0.   1.   0.]
#  [  0.   0.   0.   0.   0. 241.   0.   8.   0.   5.]
#  [ 26.   2.  13.   9.  15.   0. 165.   0.   1.   0.]
#  [  0.   0.   0.   0.   0.   2.   0. 230.   2.   8.]
#  [  3.   1.   5.   1.   1.   1.   1.   1. 244.   2.]
#  [  0.   0.   0.   0.   0.   5.   0.  11.   0. 235.]]
#
# The confusion matrix for test set in sklearn is:
#  [[432.   1.   5.  12.   2.   0.  80.   0.   1.   0.]
#  [  0. 482.   0.   0.   1.   0.   0.   0.   0.   0.]
#  [  5.   4. 410.   3.  39.   0.  53.   0.   1.   0.]
#  [ 12.   9.   7. 457.  14.   0.   9.   0.   1.   0.]
#  [  3.   0.  37.   9. 399.   0.  34.   0.   2.   0.]
#  [  0.   0.   0.   0.   0. 473.   0.  14.   2.  11.]
#  [ 38.   4.  33.  14.  39.   0. 317.   0.   2.   0.]
#  [  0.   0.   0.   0.   0.  16.   0. 471.   2.  14.]
#  [ 10.   0.   8.   5.   6.   5.   7.   1. 489.   1.]
#  [  0.   0.   0.   0.   0.   6.   0.  14.   0. 474.]]
