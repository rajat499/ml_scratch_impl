# %%
#Importing all the necessary libraries
import numpy as np
import pandas as pd
import time
from scipy.spatial.distance import pdist, cdist, squareform
from sklearn.svm import SVC
from multiprocessing import Process
import multiprocessing

# %%
#Importing data
s = time.time()
data = pd.read_csv('../fashion_mnist/train.csv', header=None)
data = data.to_numpy()
y = data[:,-1]
data = data[:,:-1]
data /= 255
print("Data imported in: ", time.time()-s, "s")

#All the different desired values of C
C = [1e-5, 1e-3, 1, 5, 10]
gamma = 0.05

#Importing Validation set
data_val = pd.read_csv('../fashion_mnist/val.csv', header=None)
data_val = data_val.to_numpy()
y_val = data_val[:,-1]
data_val = data_val[:,:-1]
data_val /= 255

data = np.concatenate((data, data_val), axis = 0)
y = np.concatenate((y,y_val))
# Out:
# Data imported in:  3.833005905151367 s

# %%
#Dividing the training data into 5 different folds/sets
data_cross = []
y_cross = []

for i in range(5):
    data_i = data[i*5000:(i+1)*5000][:]
    y_i = y[i*5000:(i+1)*5000]
    data_cross.append(data_i)
    y_cross.append(y_i)
data = np.array(data_cross)
y = np.array(y_cross)

data_cross = []
y_cross = []

# %%
#Function to train a Multi Class Sklearn's SVM modelf over data_x
# and then calculating accuracy over data_val and data_test
#This function will be used in Multiprocessing

def svm_ovo(data_x, data_y, data_val, y_val, data_test, y_test, c_acc, t_acc, index, C):
    print("Started SVM executing for C=",c, " index=", index)
    s = time.time()
    clf = SVC(C=C, kernel='rbf', gamma=0.05, decision_function_shape='ovo')
    clf.fit(data_x, data_y)
    c_acc[index] = clf.score(data_val, y_val)
    t_acc[index] = clf.score(data_test, y_test)
    print("C=",c," index=",index," val-",c_acc[index], "test - ",t_acc[index])
    print("Done SVM executing for C=",c, " index=", index," in ", time.time()-s)

# %%
#Training a 5-fold model over data set for a particular value of C
#This function uses MULTIPROCESSING to train all the 5 models in parallel
#It tests all the 5 models over the test set data_test

def cross_fold(data, y, data_test, y_test, C):
    
    process = []
    manager = multiprocessing.Manager()
    c_acc = manager.dict()
    t_acc = manager.dict()
    for i in range(5):
        data_x = np.zeros((0,data.shape[2]))
        data_y = []
        for j in range(5):
            if(j==i):
                continue
            else:
                data_x = np.concatenate((data_x, data[j]), axis=0)
                data_y = np.concatenate((data_y, y[j]))
        
        p = Process(target=svm_ovo, args=(data_x, data_y, data[i], y[i], data_test, y_test, c_acc, t_acc, i, C))
        p.start()
        process.append(p)
        
    for p in process:
        p.join()
        
    cross_fold_acc = np.sum(c_acc.values())/len(c_acc)
    
    test_acc = np.sum(t_acc.values())/len(t_acc)
    
    return cross_fold_acc, test_acc

# %%
#Importing Test Data
data_test = pd.read_csv('../fashion_mnist/test.csv', header=None)
data_test = data_test.to_numpy()
y_test = data_test[:,-1]
data_test = data_test[:,:-1]
data_test /= 255

# %%
#Training models for different values of C and reporting their accuracies for comparison.
for c in C:
    print("Going for C=",c)
    s1 = time.time()
    cross_fold_acc, test_acc = cross_fold(data, y, data_test, y_test, c)
    print("Done for C=",c," in ",time.time()-s1)
    print("The reported 5-fold Cross validation accuarcy is ", cross_fold_acc*100,"% and test accuarcy is", test_acc*100,"%")
# Out:
# Going for C= 1e-05
# Started SVM executing for C= 1e-05  index= 0
# Started SVM executing for C= 1e-05  index= 1
# Started SVM executing for C= 1e-05  index= 2
# Started SVM executing for C= 1e-05  index= 3
# Started SVM executing for C= 1e-05  index= 4
# C= 1e-05  index= 1  val- 0.0946 test -  0.1
# Done SVM executing for C= 1e-05  index= 1  in  1429.9486751556396
# C= 1e-05  index= 0  val- 0.0946 test -  0.1
# Done SVM executing for C= 1e-05  index= 0  in  1437.8389213085175
# C= 1e-05  index= 3  val- 0.0924 test -  0.1
# Done SVM executing for C= 1e-05  index= 3  in  1450.5666944980621
# C= 1e-05  index= 4  val- 0.0964 test -  0.1
# Done SVM executing for C= 1e-05  index= 4  in  1467.7786486148834
# C= 1e-05  index= 2  val- 0.0962 test -  0.1
# Done SVM executing for C= 1e-05  index= 2  in  1469.8736338615417
# Done for C= 1e-05  in  1488.7275114059448
# The reported 5-fold Cross validation accuarcy is  9.484 % and test accuarcy is 10.0 %
# Going for C= 0.001
# Started SVM executing for C= 0.001  index= 0
# Started SVM executing for C= 0.001  index= 1
# Started SVM executing for C= 0.001  index= 2
# Started SVM executing for C= 0.001  index= 3
# Started SVM executing for C= 0.001  index= 4
# C= 0.001  index= 0  val- 0.0946 test -  0.1
# Done SVM executing for C= 0.001  index= 0  in  1410.5343716144562
# C= 0.001  index= 3  val- 0.0924 test -  0.1
# Done SVM executing for C= 0.001  index= 3  in  1413.588282585144
# C= 0.001  index= 1  val- 0.0946 test -  0.1
# Done SVM executing for C= 0.001  index= 1  in  1414.378295660019
# C= 0.001  index= 2  val- 0.0962 test -  0.1
# Done SVM executing for C= 0.001  index= 2  in  1499.8615317344666
# C= 0.001  index= 4  val- 0.0964 test -  0.1
# Done SVM executing for C= 0.001  index= 4  in  1501.7552349567413
# Done for C= 0.001  in  2990.992471218109
# The reported 5-fold Cross validation accuarcy is  9.484 % and test accuarcy is 10.0 %
# Going for C= 1
# Started SVM executing for C= 1  index= 0
# Started SVM executing for C= 1  index= 1
# Started SVM executing for C= 1  index= 2
# Started SVM executing for C= 1  index= 3
# Started SVM executing for C= 1  index= 4
# C= 1  index= 2  val- 0.8838 test -  0.8752
# Done SVM executing for C= 1  index= 2  in  482.8479998111725
# C= 1  index= 3  val- 0.8766 test -  0.8736
# Done SVM executing for C= 1  index= 3  in  487.4037594795227
# C= 1  index= 4  val- 0.8882 test -  0.875
# Done SVM executing for C= 1  index= 4  in  487.7033407688141
# C= 1  index= 1  val- 0.8778 test -  0.875
# Done SVM executing for C= 1  index= 1  in  488.5333323478699
# C= 1  index= 0  val- 0.8778 test -  0.8768
# Done SVM executing for C= 1  index= 0  in  491.87104892730713
# Done for C= 1  in  3482.9865486621857
# The reported 5-fold Cross validation accuarcy is  88.084 % and test accuarcy is 87.51200000000001 %
# Going for C= 5
# Started SVM executing for C= 5  index= 0
# Started SVM executing for C= 5  index= 1
# Started SVM executing for C= 5  index= 2
# Started SVM executing for C= 5  index= 3
# Started SVM executing for C= 5  index= 4
# C= 5  index= 3  val- 0.8846 test -  0.8794
# Done SVM executing for C= 5  index= 3  in  504.855251789093
# C= 5  index= 2  val- 0.8922 test -  0.8804
# Done SVM executing for C= 5  index= 2  in  515.8242025375366
# C= 5  index= 1  val- 0.883 test -  0.8796
# Done SVM executing for C= 5  index= 1  in  517.7108314037323
# C= 5  index= 4  val- 0.8902 test -  0.8826
# Done SVM executing for C= 5  index= 4  in  527.6213600635529
# C= 5  index= 0  val- 0.881 test -  0.8796
# Done SVM executing for C= 5  index= 0  in  528.9342143535614
# Done for C= 5  in  4012.044776916504
# The reported 5-fold Cross validation accuarcy is  88.62 % and test accuarcy is 88.032 %
# Going for C= 10
# Started SVM executing for C= 10  index= 0
# Started SVM executing for C= 10  index= 1
# Started SVM executing for C= 10  index= 2
# Started SVM executing for C= 10  index= 3
# Started SVM executing for C= 10  index= 4
# C= 10  index= 1  val- 0.882 test -  0.8792
# Done SVM executing for C= 10  index= 1  in  505.2648868560791
# C= 10  index= 4  val- 0.891 test -  0.8822
# Done SVM executing for C= 10  index= 4  in  508.0814640522003
# C= 10  index= 3  val- 0.8842 test -  0.8804
# Done SVM executing for C= 10  index= 3  in  508.9838583469391
# C= 10  index= 2  val- 0.8922 test -  0.8804
# Done SVM executing for C= 10  index= 2  in  534.4798548221588
# C= 10  index= 0  val- 0.8806 test -  0.879
# Done SVM executing for C= 10  index= 0  in  535.3374531269073
# Done for C= 10  in  4547.504848480225
# The reported 5-fold Cross validation accuarcy is  88.6 % and test accuarcy is 88.02399999999999 %
